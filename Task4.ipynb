# %%
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from textblob import TextBlob
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'textblob'

# %%
# !pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
#   Downloading textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting nltk>=3.9 (from textblob)
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting click (from nltk>=3.9->textblob)
#   Downloading click-8.3.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: joblib in c:\users\munni\appdata\local\programs\python\python314\lib\site-packages (from nltk>=3.9->textblob) (1.5.2)
# Collecting regex>=2021.8.3 (from nltk>=3.9->textblob)
#   Downloading regex-2025.10.23-cp314-cp314-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk>=3.9->textblob)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\users\munni\appdata\local\programs\python\python314\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Downloading textblob-0.19.0-py3-none-any.whl (624 kB)
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------------------------------- 624.3/624.3 kB 3.0 MB/s  0:00:00
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    --------------------------- ------------ 1.0/1.5 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 5.5 MB/s  0:00:00
# Downloading regex-2025.10.23-cp314-cp314-win_amd64.whl (280 kB)
# Downloading click-8.3.0-py3-none-any.whl (107 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, click, nltk, textblob
#
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    -------- ------------------------------- 1/5 [regex]
#    -------- ------------------------------- 1/5 [regex]
#    ---------------- ----------------------- 2/5 [click]
#    ---------------- ----------------------- 2/5 [click]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    -------------------------------- ------- 4/5 [textblob]
#    -------------------------------- ------- 4/5 [textblob]
#    -------------------------------- ------- 4/5 [textblob]
#    ---------------------------------------- 5/5 [textblob]
#
# Successfully installed click-8.3.0 nltk-3.9.2 regex-2025.10.23 textblob-0.19.0 tqdm-4.67.1
#   WARNING: Connection timed out while downloading.
#   WARNING: Attempting to resume incomplete download (0 bytes/4.4 kB, attempt 1)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from textblob import TextBlob

# %%
data= pd.read_csv('twitter_training.csv')

# %%
data.head()
# Out:
#    2401  Borderlands  Positive  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#   im getting on borderlands and i will murder you all ,
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %%
col_names=['ID','Entity','Sentiments','Contest']
df=pd.read_csv('twitter_training.csv', names=col_names)

# %%
df.head()
# Out:
#      ID       Entity Sentiments  \
# 0  2401  Borderlands   Positive
# 1  2401  Borderlands   Positive
# 2  2401  Borderlands   Positive
# 3  2401  Borderlands   Positive
# 4  2401  Borderlands   Positive
#
#                                              Contest
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...

# %%
df.shape
# Out:
# (74682, 4)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of          ID       Entity Sentiments  \
# 0      2401  Borderlands   Positive
# 1      2401  Borderlands   Positive
# 2      2401  Borderlands   Positive
# 3      2401  Borderlands   Positive
# 4      2401  Borderlands   Positive
# ...     ...          ...        ...
# 74677  9200       Nvidia   Positive
# 74678  9200       Nvidia   Positive
# 74679  9200       Nvidia   Positive
# 74680  9200       Nvidia   Positive
# 74681  9200       Nvidia   Positive
#
#                                                  Contest
# 0      im getting on borderlands and i will murder yo...
# 1      I am coming to the borders and I will kill you...
# 2      im getting on borderlands and i will kill you ...
# 3      im coming on borderlands and i will murder you...
# 4      im getting on borderlands 2 and i will murder ...
# ...                                                  ...
# 74677  Just realized that the Windows partition of my...
# 74678  Just realized that my Mac window partition is ...
# 74679  Just realized the windows partition of my Mac ...
# 74680  Just realized between the windows partition of...
# 74681  Just like the windows partition of my Mac is l...
#
# [74682 rows x 4 columns]>

# %%
df.isnull().sum()
# Out:
# ID              0
# Entity          0
# Sentiments      0
# Contest       686
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# ID            0
# Entity        0
# Sentiments    0
# Contest       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(2340)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (71656, 4)

# %%
sentiment_counts=df['Sentiments'].value_counts()
sentiment_counts
# Out:
# Sentiments
# Negative      21698
# Positive      19713
# Neutral       17708
# Irrelevant    12537
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,3))
sns.scatterplot(data=data, x="Age", y="Fare", hue="Age", palette="coolwarm")  # change color palette
plt.title("Scatter plot of Age and Fare")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.legend(title="Age")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 plt.figure(figsize=(6,3))
# ----> 2 sns.scatterplot(data=data, x="Age", y="Fare", hue="Age", palette="coolwarm")  # change color palette
#       3 plt.title("Scatter plot of Age and Fare")
#       4 plt.xlabel("Age")
#
# NameError: name 'sns' is not defined

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,3))
sentiment_counts.plot(kind='bar', color=['red','green','blue','yellow'])
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()

# %%
brand_data=df[df['Entity'].str.contains('Microsoft',case=False)]
brand_sentiment_counts=brand_data['Sentiments'].value_counts()
brand_sentiment_counts
# Out:
# Sentiments
# Neutral       816
# Negative      748
# Positive      573
# Irrelevant    167
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))
plt.pie(brand_sentiment_counts,labels=brand_sentiment_counts.index,autopct='%1.11f%%',startangle=140)
plt.show()
